# %% [markdown]
# # Reead, tranform  and analize data #

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Temor, raiz de todo mal
# La muerte es una quimera, mientras to existo, no existe la muerte
# y cuento existe ella, ya no existo yo
# lo mejor de la mascara, es que te paraliza
# como los miedos, aquellos que te evitan avanzar en la vida

# %%
total_sells = "clean_sells.csv"

# %%
try:
    df = pd.read_csv(total_sells) 
    print(f"Excel {total_sells} read correctly, size {df.shape}" )
except FileNotFoundError:
    print(f"El archivo '{total_sells}' no se encontró.")
except Exception as e:
    print(f"Ocurrió un error al leer el archivo: {str(e)}")


df["Fecha"] = pd.to_datetime(df["Fecha"])
df
# Out:
# Excel clean_sells.csv read correctly, size (29918, 21)
#        Unnamed: 0  Codigo_venta      Fecha  Almacen  Caja   T_C  \
# 0               0          8619 2016-04-01      166    10  6.96
# 1               1          8619 2016-04-01      166    10  6.96
# 2               2          8620 2016-04-01      161    10  6.96
# 3               3          8620 2016-04-01      161    10  6.96
# 4               4          8621 2016-04-01      161    10  6.96
# ...           ...           ...        ...      ...   ...   ...
# 29913       29924         32049 2021-08-05      162    10  6.96
# 29914       29925         32050 2021-08-05      165    10  6.96
# 29915       29926         32050 2021-08-05      165    10  6.96
# 29916       29927         32051 2021-08-05      164    10  6.96
# 29917       29928         32051 2021-08-05      164    10  6.96
#
#       Codigo_cliente                    Nombre_cliente  Codigo_vendedor  \
# 0             60-747                   WILFREDO MENDEZ             73.0
# 1             60-747                   WILFREDO MENDEZ             73.0
# 2             41-286                   SILVERIO CHOQUE             42.0
# 3             41-286                   SILVERIO CHOQUE             42.0
# 4             63-044  EMPRESA CONSTRUCTORA ROLY S.R.L.             42.0
# ...              ...                               ...              ...
# 29913              O                 BENEDICTO ALVAREZ             32.0
# 29914         66-796        CONSTRUCTORA ORBANCO S.R.L             24.0
# 29915         66-796        CONSTRUCTORA ORBANCO S.R.L             24.0
# 29916         60-743                         WIWOGREEN             67.0
# 29917         60-743                         WIWOGREEN             67.0
#
#       Codigo_proyecto  ...                Nombre_producto  \
# 0               P-006  ...                 ACOPLE DE 32mm
# 1               P-006  ...       SUPERTUBO® HDPE DE  32mm
# 2               P-003  ...      ADAPTADOR MACHO DE 32 x 1
# 3               P-003  ...    ADAPTADOR MACHO DE 20 x 1/2
# 4               P-003  ...       SUPERTUBO® HDPE DE  32mm
# ...               ...  ...                            ...
# 29913              VP  ...    ADAPTADOR MACHO DE 25 x 3/4
# 29914              vp  ...       SUPERTUBO® HDPE DE 110mm
# 29915              vp  ...       SUPERTUBO® HDPE DE  90mm
# 29916              VP  ...      ADAPTADOR MACHO DE 32 x 1
# 29917              VP  ...  ADAPTADOR MACHO DE 40 x 1 1/4
#
#                        Linea_producto Cantidad_vendida  Precio_total  \
# 0                      POLYWARE PN 16              2.0          49.4
# 1      ®PE100 SDR13.6 PN12.5 ISO 4427            100.0         820.0
# 2                      POLYWARE PN 16              2.0          22.4
# 3                      POLYWARE PN 16              6.0          30.6
# 4      ®PE100 SDR13.6 PN12.5 ISO 4427            400.0        3280.0
# ...                               ...              ...           ...
# 29913                  POLYWARE PN 16              4.0          32.4
# 29914      ®PE100 SDR17 PN10 ISO 4427            800.0       39728.0
# 29915      ®PE100 SDR17 PN10 ISO 4427            600.0       20130.0
# 29916                  POLYWARE PN 16              2.0          22.4
# 29917                  POLYWARE PN 16              2.0          38.2
#
#        Total_descuento  Total_facturado  Total_impuesto  Total_venta  \
# 0                  0.0             49.4               0         49.4
# 1                 20.0            800.0               0        800.0
# 2                  0.0             22.4               0         22.4
# 3                  0.0             30.6               0         30.6
# 4                  0.0           3280.0               0       3280.0
# ...                ...              ...             ...          ...
# 29913              0.0             32.4               0         32.4
# 29914              0.0          39728.0               0      39728.0
# 29915              0.0          20130.0               0      20130.0
# 29916              0.0             22.4               0         22.4
# 29917              0.0             38.2               0         38.2
#
#        Total_contado  Total_credito
# 0                  0           49.4
# 1                  0          800.0
# 2                  0           22.4
# 3                  0           30.6
# 4                  0         3280.0
# ...              ...            ...
# 29913              0           32.4
# 29914              0        39728.0
# 29915              0        20130.0
# 29916              0           22.4
# 29917              0           38.2
#
# [29918 rows x 21 columns]

# %% [markdown]
# **Analyze and visualize**

# %%
df.describe()
# Out:
#          Unnamed: 0  Codigo_venta                          Fecha  \
# count  29918.000000  29918.000000                          29918
# mean   14963.189685  19711.475834  2018-12-21 09:03:35.870045184
# min        0.000000   8619.000000            2016-04-01 00:00:00
# 25%     7481.250000  12455.000000            2017-07-20 00:00:00
# 50%    14961.500000  17401.500000            2018-07-30 00:00:00
# 75%    22444.750000  27280.000000            2020-08-27 00:00:00
# max    29928.000000  32051.000000            2021-08-05 00:00:00
# std     8639.880747   7765.713002                            NaN
#
#             Almacen     Caja           T_C  Codigo_vendedor  Cantidad_vendida  \
# count  29918.000000  29918.0  29918.000000     29918.000000      29918.000000
# mean     154.480580     10.0      6.928524        37.429641        196.276249
# min      111.000000     10.0      6.860000        11.000000          0.500000
# 25%      161.000000     10.0      6.860000        22.000000          2.000000
# 50%      162.000000     10.0      6.960000        33.000000          4.000000
# 75%      163.000000     10.0      6.960000        51.000000         30.000000
# max      411.000000     10.0      6.960000        74.000000     164909.560000
# std       19.330336      0.0      0.046262        15.576563       1359.286850
#
#        Precio_total  Total_descuento  Total_facturado  Total_impuesto  \
# count  2.991800e+04     29918.000000     2.991800e+04         29918.0
# mean   7.225284e+03       233.927474     6.991357e+03             0.0
# min    5.000000e-01    -64647.370000     5.000000e-01             0.0
# 25%    5.130000e+01         0.000000     5.130000e+01             0.0
# 50%    2.177000e+02         0.000000     2.177000e+02             0.0
# 75%    1.387500e+03         0.000000     1.361500e+03             0.0
# max    5.898700e+06    221014.500000     5.898700e+06             0.0
# std    7.281930e+04      3408.298801     7.231462e+04             0.0
#
#         Total_venta  Total_contado  Total_credito
# count  2.991800e+04        29918.0   2.991800e+04
# mean   6.991357e+03            0.0   6.991357e+03
# min    5.000000e-01            0.0   5.000000e-01
# 25%    5.130000e+01            0.0   5.130000e+01
# 50%    2.177000e+02            0.0   2.177000e+02
# 75%    1.361500e+03            0.0   1.361500e+03
# max    5.898700e+06            0.0   5.898700e+06
# std    7.231462e+04            0.0   7.231462e+04

# %%
df.dtypes
# Out:
# Unnamed: 0                   int64
# Codigo_venta                 int64
# Fecha               datetime64[ns]
# Almacen                      int64
# Caja                         int64
# T_C                        float64
# Codigo_cliente              object
# Nombre_cliente              object
# Codigo_vendedor            float64
# Codigo_proyecto             object
# Codigo_producto             object
# Nombre_producto             object
# Linea_producto              object
# Cantidad_vendida           float64
# Precio_total               float64
# Total_descuento            float64
# Total_facturado            float64
# Total_impuesto               int64
# Total_venta                float64
# Total_contado                int64
# Total_credito              float64
# dtype: object

# %%
df.count()
# Out:
# Unnamed: 0          29918
# Codigo_venta        29918
# Fecha               29918
# Almacen             29918
# Caja                29918
# T_C                 29918
# Codigo_cliente      29918
# Nombre_cliente      29918
# Codigo_vendedor     29918
# Codigo_proyecto     29918
# Codigo_producto     29918
# Nombre_producto     29918
# Linea_producto      29918
# Cantidad_vendida    29918
# Precio_total        29918
# Total_descuento     29918
# Total_facturado     29918
# Total_impuesto      29918
# Total_venta         29918
# Total_contado       29918
# Total_credito       29918
# dtype: int64

# %%
# Group by 'Codigo_vendedor' and aggregate both the count and sum of 'Total_venta'
total_sells_by_seller = df.groupby("Codigo_vendedor")['Total_venta'].agg(['count', 'sum'])

# Calculate the average sale amount by dividing the sum by the count
total_sells_by_seller['avg_by_sell'] = total_sells_by_seller['sum'] / total_sells_by_seller['count']

total_sells_by_seller
# Out:
#                  count          sum   avg_by_sell
# Codigo_vendedor
# 11.0               138    550211.67   3987.041087
# 14.0              2398  16708642.63   6967.740880
# 15.0                53    262536.20   4953.513208
# 16.0               307  14138599.00  46054.068404
# 17.0              1755  25672976.66  14628.476729
# 18.0                43     66936.27   1556.657442
# 22.0              3094  50062475.60  16180.502780
# 23.0               704   5334829.68   7577.883068
# 24.0               680   3393821.15   4990.913456
# 31.0              1182  12816669.45  10843.205964
# 32.0              2956  14789523.92   5003.221894
# 33.0              1655   3167523.32   1913.911372
# 34.0               279    855004.20   3064.531183
# 41.0               683   9534080.18  13959.121786
# 42.0              2486   7332885.32   2949.672293
# 44.0               375    550060.71   1466.828560
# 45.0               634   1267673.32   1999.484732
# 46.0               328    313668.30    956.305793
# 47.0                10     14852.80   1485.280000
# 48.0               481   1782856.39   3706.562141
# 51.0              2727   4216794.76   1546.312710
# 52.0              2505  17214840.47   6872.191804
# 53.0              1311    547336.68    417.495561
# 54.0               912    601728.97    659.790537
# 60.0                 1        53.90     53.900000
# 61.0               564   8427469.35  14942.321543
# 63.0                 1     21794.40  21794.400000
# 65.0               331   2159329.30   6523.653474
# 66.0               560   2647054.74   4726.883464
# 67.0                76     33452.60    440.165789
# 72.0                61   1695910.67  27801.814262
# 73.0               618   2980174.96   4822.289579
# 74.0                10      5646.00    564.600000

# %%
total_sells_by_seller['sum'].plot(kind="bar", figsize=(10,6), title="Total sells by seller")
plt.xlabel("Codigo de vendedor")
plt.ylabel("Suma de ventas totales")
plt.show()

# %%
total_sells_by_seller['avg_by_sell'].plot(kind="bar", figsize=(10,6), title="avg sells by seller")
plt.xlabel("Codigo de vendedor")
plt.ylabel("Promedio de ventas por vendedor")
plt.show()

# %%
total_sells_by_day = df.groupby("Fecha")['Total_venta'].agg(['count', 'sum'])

total_sells_by_day['avg_by_day'] = total_sells_by_day.apply(lambda x : x["sum"]/x["count"] if x["count"]>0  else 0, axis=1 )

total_sells_by_day
# Out:
#             count        sum    avg_by_day
# Fecha
# 2016-04-01     30   77025.60   2567.520000
# 2016-04-02      5    2325.50    465.100000
# 2016-04-04     34   40311.10   1185.620588
# 2016-04-05     25  906060.36  36242.414400
# 2016-04-06     37   34550.80    933.805405
# ...           ...        ...           ...
# 2021-07-31     27  445666.16  16506.154074
# 2021-08-02    130  645252.24   4963.478769
# 2021-08-03     69  194136.66   2813.574783
# 2021-08-04     79  450312.96   5700.164051
# 2021-08-05     47  430202.10   9153.236170
#
# [743 rows x 3 columns]

# %%
total_sells_by_day['avg_by_day'].plot(kind="line", figsize=(10,6), title="avg sells by day")
plt.xlabel("Codigo de vendedor")
plt.ylabel("Promedio de ventas por vendedor")
plt.show()

# %% [markdown]
# # Data Expand #

# %% [markdown]
# ### Date expand

# %% [markdown]
# Add day, month and year

# %%
df["Dia_Semana"] = df["Fecha"].dt.strftime('%A')
df["Mes"] = df["Fecha"].dt.month
df["Ano"] = df["Fecha"].dt.year

# %% [markdown]
# ### Product details

# %% [markdown]
# Unit priece

# %%
df["Precio_unitario"] = df["Precio_total"] / df["Cantidad_vendida"]
df.head(1)
# Out:
#    Unnamed: 0  Codigo_venta      Fecha  Almacen  Caja   T_C Codigo_cliente  \
# 0           0          8619 2016-04-01      166    10  6.96         60-747
#
#     Nombre_cliente  Codigo_vendedor Codigo_proyecto  ... Total_descuento  \
# 0  WILFREDO MENDEZ             73.0           P-006  ...             0.0
#
#   Total_facturado Total_impuesto  Total_venta  Total_contado  Total_credito  \
# 0            49.4              0         49.4              0           49.4
#
#    Dia_Semana  Mes   Ano  Precio_unitario
# 0      Friday    4  2016             24.7
#
# [1 rows x 25 columns]

# %% [markdown]
# Caregories from name

# %%
df['Ultimo_caracter'] = df['Codigo_producto'].str[-1]
df.groupby(["Ultimo_caracter"])["Codigo_venta"].count()
# Out:
# Ultimo_caracter
# 0        3
# 1       55
# 2        4
# A        2
# C    22633
# E       44
# K       42
# M      169
# P     6705
# T       28
# U       11
# Z      222
# Name: Codigo_venta, dtype: int64

# %%
print(df.groupby(["Ultimo_caracter"])["Codigo_venta"].count())
# Out:
# Ultimo_caracter
# 0        3
# 1       55
# 2        4
# A        2
# C    22633
# E       44
# K       42
# M      169
# P     6705
# T       28
# U       11
# Z      222
# Name: Codigo_venta, dtype: int64

# %%
df[df["Ultimo_caracter"]=="1"][["Codigo_producto","Nombre_producto","Linea_producto"]]
# Out:
#             Codigo_producto                 Nombre_producto  \
# 104       ZT20-000000000001             TRANSPORTE NACIONAL
# 370       ZT20-000000000001             TRANSPORTE NACIONAL
# 377       ZT20-000000000001             TRANSPORTE NACIONAL
# 444                  ZT20-1                    MOVILIZACIÓN
# 604       ZT20-000000000001             TRANSPORTE NACIONAL
# 665       A350101-110X110M1   ADAPTADOR C/BRIDA METAL 110mm
# 862       ZT20-000000000001             TRANSPORTE NACIONAL
# 1122                 ZT20-1                    MOVILIZACIÓN
# 1158      A350101-110X110M1   ADAPTADOR C/BRIDA METAL 110mm
# 1495      ZT20-000000000001             TRANSPORTE NACIONAL
# 1588      ZT20-000000000001             TRANSPORTE NACIONAL
# 1591                 ZT20-1                    MOVILIZACIÓN
# 1909      ZT20-000000000001             TRANSPORTE NACIONAL
# 1953      ZT20-000000000001             TRANSPORTE NACIONAL
# 1980      ZT20-000000000001             TRANSPORTE NACIONAL
# 2342      ZT20-000000000001             TRANSPORTE NACIONAL
# 2743                 ZT20-1                    MOVILIZACIÓN
# 2952      ZT20-000000000001             TRANSPORTE NACIONAL
# 2965                 ZT20-1                    MOVILIZACIÓN
# 3021      ZT20-000000000001             TRANSPORTE NACIONAL
# 3083      ZT20-000000000001             TRANSPORTE NACIONAL
# 3106      A350101-110X110M1   ADAPTADOR C/BRIDA METAL 110mm
# 3273      ZT20-000000000001             TRANSPORTE NACIONAL
# 3617                 ZT20-1                    MOVILIZACIÓN
# 3982                 ZT20-1                    MOVILIZACIÓN
# 4464      ZT20-000000000001             TRANSPORTE NACIONAL
# 4939      ZT20-000000000001             TRANSPORTE NACIONAL
# 5123      ZT20-000000000001             TRANSPORTE NACIONAL
# 5377                 ZT20-1                    MOVILIZACIÓN
# 5427                 ZT20-1                    MOVILIZACIÓN
# 5586      ZT20-000000000001             TRANSPORTE NACIONAL
# 6176                 ZT20-1                    MOVILIZACIÓN
# 6600                 ZT20-1                    MOVILIZACIÓN
# 6746     ZT10-0000000000001                TRANSPORTE LOCAL
# 7002                 ZT20-1                    MOVILIZACIÓN
# 7005      ZT20-000000000001             TRANSPORTE NACIONAL
# 7037                 ZT20-1                    MOVILIZACIÓN
# 7556      ZT20-000000000001             TRANSPORTE NACIONAL
# 7609     ZT10-0000000000001                TRANSPORTE LOCAL
# 7974      ZT20-000000000001             TRANSPORTE NACIONAL
# 14358     A350101-110X110M1   ADAPTADOR C/BRIDA METAL 110mm
# 15935  A370061-025X090000N1   CUELLERA T/en carga 25mmX90mm
# 15952  A370061-025X063000N1   CUELLERA T/en carga 25mmX63mm
# 15953  A370061-020X075000N1   CUELLERA T/en carga 20mmX75mm
# 15954  A370061-025X075000N1   CUELLERA T/en carga 25mmX75mm
# 15955  A370061-020X090000N1   CUELLERA T/en carga 20mmX90mm
# 15956  A370061-020X110000N1  CUELLERA T/en carga 20mmX110mm
# 15958  A370061-025X110000N1  CUELLERA T/en carga 25mmX110mm
# 16943  A370061-020X063000N1   CUELLERA T/en carga 20mmX63mm
# 17269     A350101-110X110M1   ADAPTADOR C/BRIDA METAL 110mm
# 17663     A350101-110X110M1   ADAPTADOR C/BRIDA METAL 110mm
# 18102     A350101-110X110M1   ADAPTADOR C/BRIDA METAL 110mm
# 24398     A350101-110X110M1   ADAPTADOR C/BRIDA METAL 110mm
# 26699     A350101-063X063M1    ADAPTADOR C/BRIDA METAL 63mm
# 28490     A350101-110X110M1   ADAPTADOR C/BRIDA METAL 110mm
#
#                Linea_producto
# 104                  SERVICIO
# 370                  SERVICIO
# 377                  SERVICIO
# 444                  SERVICIO
# 604                  SERVICIO
# 665            POLYWARE PN 10
# 862                  SERVICIO
# 1122                 SERVICIO
# 1158           POLYWARE PN 10
# 1495                 SERVICIO
# 1588                 SERVICIO
# 1591                 SERVICIO
# 1909                 SERVICIO
# 1953                 SERVICIO
# 1980                 SERVICIO
# 2342                 SERVICIO
# 2743                 SERVICIO
# 2952                 SERVICIO
# 2965                 SERVICIO
# 3021                 SERVICIO
# 3083                 SERVICIO
# 3106           POLYWARE PN 10
# 3273                 SERVICIO
# 3617                 SERVICIO
# 3982                 SERVICIO
# 4464                 SERVICIO
# 4939                 SERVICIO
# 5123                 SERVICIO
# 5377                 SERVICIO
# 5427                 SERVICIO
# 5586                 SERVICIO
# 6176                 SERVICIO
# 6600                 SERVICIO
# 6746                 SERVICIO
# 7002                 SERVICIO
# 7005                 SERVICIO
# 7037                 SERVICIO
# 7556                 SERVICIO
# 7609                 SERVICIO
# 7974                 SERVICIO
# 14358          POLYWARE PN 10
# 15935  UNIDELTA PN 16 ELECTRO
# 15952  UNIDELTA PN 16 ELECTRO
# 15953  UNIDELTA PN 16 ELECTRO
# 15954  UNIDELTA PN 16 ELECTRO
# 15955  UNIDELTA PN 16 ELECTRO
# 15956  UNIDELTA PN 16 ELECTRO
# 15958  UNIDELTA PN 16 ELECTRO
# 16943  UNIDELTA PN 16 ELECTRO
# 17269          POLYWARE PN 10
# 17663          POLYWARE PN 10
# 18102          POLYWARE PN 10
# 24398          POLYWARE PN 10
# 26699          POLYWARE PN 10
# 28490          POLYWARE PN 10

# %%
df["Tipo_producto"] = np.where(df["Codigo_producto"].str.startswith("Z"), "SERVICIO", "DESCONOCIDO")

# %%
df["Tipo_producto"] = df["Tipo_producto"].where(~((df["Tipo_producto"] == "DESCONOCIDO") & (df["Codigo_producto"].str.endswith("P"))), "PRODUCIDO")
df["Tipo_producto"] = df["Tipo_producto"].where(~((df["Tipo_producto"] == "DESCONOCIDO") & (df["Codigo_producto"].str.endswith("C"))), "COMPRADO")
df["Tipo_producto"] = df["Tipo_producto"].where(~((df["Tipo_producto"] == "DESCONOCIDO") & (df["Codigo_producto"].str.endswith("E"))), "INTERESES")

# %%
df[df["Tipo_producto"]=="DESCONOCIDO"][["Codigo_producto", "Tipo_producto","Nombre_producto"]]
# Out:
#           Codigo_producto Tipo_producto                 Nombre_producto
# 407    A530010-060-000S1K   DESCONOCIDO               KIT PILETA DE 1/2
# 665     A350101-110X110M1   DESCONOCIDO   ADAPTADOR C/BRIDA METAL 110mm
# 1158    A350101-110X110M1   DESCONOCIDO   ADAPTADOR C/BRIDA METAL 110mm
# 1349   A210000-030-000S1K   DESCONOCIDO  TORRE HIDRONEUMÁTICA 4 CILIND.
# 1474   A530010-060-000S1K   DESCONOCIDO               KIT PILETA DE 1/2
# ...                   ...           ...                             ...
# 29663  A365210-400-000N1T   DESCONOCIDO          TEE HDPE DE 400 MM SEG
# 29684  A356110-400X355N1K   DESCONOCIDO        REDUCCION HDPE 400X355MM
# 29773  A356116-160X140N2K   DESCONOCIDO        REDUCCION HDPE 160X140MM
# 29844  A365116-315-000N2T   DESCONOCIDO     CODO HDPE 90º DE 315 MM SEG
# 29845  A365120-400-000N9T   DESCONOCIDO     CODO HDPE 90º DE 400 MM SEG
#
# [99 rows x 3 columns]

# %%
df.groupby(["Tipo_producto","Ultimo_caracter"])["Codigo_venta"].count()
# Out:
# Tipo_producto  Ultimo_caracter
# COMPRADO       C                  22633
# DESCONOCIDO    1                     18
#                K                     42
#                T                     28
#                U                     11
# PRODUCIDO      P                   6705
# SERVICIO       0                      3
#                1                     37
#                2                      4
#                A                      2
#                E                     44
#                M                    169
#                Z                    222
# Name: Codigo_venta, dtype: int64

# %% [markdown]
# ### Vendors name

# %% [markdown]
# add vendors name

# %%
vendors_file = ("./vendedores.xlsx")
try:
    vendors_df = pd.read_excel(vendors_file)
    print(f"Excel {vendors_file} read correctly, size {df.ndim}" )
except FileNotFoundError:
    print(f"El archivo '{vendors_file}' no se encontró.")
except Exception as e:
    print(f"Ocurrió un error al leer el archivo: {str(e)}")
# diccionario_resultante = df_clean.groupby('Codigo_producto')['Linea_producto'].unique().apply(list).to_dict()
# print(diccionario_resultante)
vendors_dictionary = vendors_df.set_index('Código')['Nombre_vendedor'].to_dict()
print(vendors_dictionary)
# Out:
# Excel ./vendedores.xlsx read correctly, size 2
# {10: 'COCHABAMBA', 11: 'Juan Carlos Camacho', 12: 'Alvaro Lopez', 13: 'Antonio Becerra', 14: 'Elizabeth Rios', 15: 'Fabiola Ortiz', 16: 'Hugo Baldivieso', 17: 'Christian Gallardo', 18: 'Mauricio Rivadineira', 19: 'Maren Mendoza', 20: 'LA PAZ', 21: 'Oscar Quiroga', 22: 'Jazmin Salvatierra', 23: 'Juan Pablo Condori Catari', 24: 'Jimmy Quispe', 25: 'Walter Zúñiga', 30: 'ORURO', 31: 'Ma. Esther Tala', 32: 'Jhonny Tococosi', 33: 'Juan Condori', 34: 'Franklin Mollo', 40: 'POTOSI', 41: 'Fátima Plaza', 42: 'Daniel Ayala', 43: 'Bryan Perez', 44: 'Willams Duran', 45: 'Gerardo Tarquino', 46: 'Valentin Franco', 47: 'Victor Ali', 48: 'Reynaldo Calvo', 50: 'SUCRE', 51: 'Rolando Poppe', 52: 'Adrian Pallares', 53: 'Paul Michaga', 54: 'Rodrigo Tumiri', 60: 'SANTA CRUZ', 61: 'Alfredo Schmidt', 62: 'Miguel Zelaya', 63: 'Maria del Carmen Paniagua', 64: 'Marco Landivar', 65: 'Ingrid Oblitas ', 66: 'Juan Pablo Carvajal', 67: 'Carla Arnez', 68: 'Waldo Quisbert', 69: 'Rodrigo Oblitas', 70: 'TARIJA', 71: 'Abigail Guzmán ', 72: 'Jose Martinez', 73: 'Edwin Rodriguez', 74: 'Julia Rossel'}

# %%
df["Nombre_vendedor"] = df["Codigo_vendedor"].apply(lambda x : vendors_dictionary[x])
df.head(1)
# Out:
#    Unnamed: 0  Codigo_venta      Fecha  Almacen  Caja   T_C Codigo_cliente  \
# 0           0          8619 2016-04-01      166    10  6.96         60-747
#
#     Nombre_cliente  Codigo_vendedor Codigo_proyecto  ... Total_venta  \
# 0  WILFREDO MENDEZ             73.0           P-006  ...        49.4
#
#   Total_contado Total_credito  Dia_Semana  Mes   Ano  Precio_unitario  \
# 0             0          49.4      Friday    4  2016             24.7
#
#    Ultimo_caracter  Tipo_producto  Nombre_vendedor
# 0                C       COMPRADO  Edwin Rodriguez
#
# [1 rows x 28 columns]

# %% [markdown]
# ### Location fill

# %% [markdown]
# From almancen merge with departament

# %%
almacenes_departamento = "./almacenes.xls"
try:
    almacenes_df = pd.read_excel(almacenes_departamento)
except FileNotFoundError:
        print(f"El archivo '{almacenes_departamento}' no se encontró.")
except Exception as e:
        print(f"Ocurrió un error al leer el archivo: {str(e)}")
# Out:
# El archivo './almacenes.xls' no se encontró.

# %%
df["Almacen"].unique()
# Out:
# array([166, 161, 164, 111, 162, 163, 411, 165], dtype=int64)

# %%
departament_dictionary = {166:"TARIJA", 161:"POTOSI", 164:"SANTA_CRUZ", 111:"COCHABAMBA", 162:"ORURO", 163:"SUCRE", 411:"SANTIVAÑEZ", 165:"LA_PAZ"}

# %%
df["Departamento"] = df["Almacen"].map(departament_dictionary)

# %% [markdown]
# ### Client categories

# %% [markdown]
# Create a categorie from volum

# %%
clients_group = df.groupby(["Codigo_cliente"]).agg(
    Total_purchase=("Codigo_venta", "count"),
    Average=('Total_venta', 'mean')
)

# %%
clients_group.sort_values(["Total_purchase"])
# Out:
#                 Total_purchase       Average
# Codigo_cliente
# 60-052                       1     79.500000
# 65-668                       1     55.000000
# 63-224                       1     24.300000
# 67-555                       1   5620.000000
# 69-995                       1  11997.000000
# ...                        ...           ...
# o                          213    624.987559
# 60-777                     263   4857.134981
# 64-074                     307   1716.526352
# 30-011                     309  14607.975340
# O                         3530    200.146649
#
# [2278 rows x 2 columns]

# %%
clients_group = clients_group.reset_index()
clients_group_test = clients_group[(clients_group["Codigo_cliente"]!="o") & (clients_group["Codigo_cliente"]!="O")]
clients_group_test.describe()
# Out:
#        Total_purchase       Average
# count     2276.000000  2.276000e+03
# mean        11.500439  7.370552e+03
# std         21.893739  3.856481e+04
# min          1.000000  5.000000e+00
# 25%          2.000000  2.892111e+02
# 50%          5.000000  1.259709e+03
# 75%         11.000000  4.928304e+03
# max        309.000000  1.434697e+06

# %%
clients_group = clients_group.reset_index()
clients_group
# Out:
#       index Codigo_cliente  Total_purchase       Average
# 0         0       %41-280%               2     47.500000
# 1         1          0-050               1     98.000000
# 2         2         01-001               2    307.000000
# 3         3         01-002              26  22602.461538
# 4         4         01-004             108   7281.978704
# ...     ...            ...             ...           ...
# 2273   2273         P1-014              22    299.368182
# 2274   2274         P1-015               1   1008.000000
# 2275   2275         P1-018               5     29.020000
# 2276   2276         P1-021               6   1001.500000
# 2277   2277              o             213    624.987559
#
# [2278 rows x 4 columns]

# %% [markdown]
# **For Frecuency....|For Average**
# SMALL 0-50........      |SMALL 0-50th
# MEDIUM 50-75....        |MEDIUM 50-75
# LARGE 75>........       |LARGE  75>
# DEFAULT o and O....     |DEFAULT o and O

# %%
bins = [0, 5, 11, float('inf')]
labels = ["OCACIONAL", "HABITUAL", "FRECUENTE"]
clients_group["Frecuencia_cliente"] = pd.cut(clients_group["Total_purchase"], bins=bins, labels=labels, right=False)

# %%
bins = [0, 1.259709e+03, 4.928304e+03, float('inf')]
labels = ["PEQUENO", "MEDIANO", "GRANDE"]
clients_group["Volumen_cliente"] = pd.cut(clients_group["Total_purchase"], bins=bins, labels=labels, right=False)

# %%
clients_group
# Out:
#       index Codigo_cliente  Total_purchase       Average Frecuencia_cliente  \
# 0         0       %41-280%               2     47.500000          OCACIONAL
# 1         1          0-050               1     98.000000          OCACIONAL
# 2         2         01-001               2    307.000000          OCACIONAL
# 3         3         01-002              26  22602.461538          FRECUENTE
# 4         4         01-004             108   7281.978704          FRECUENTE
# ...     ...            ...             ...           ...                ...
# 2273   2273         P1-014              22    299.368182          FRECUENTE
# 2274   2274         P1-015               1   1008.000000          OCACIONAL
# 2275   2275         P1-018               5     29.020000           HABITUAL
# 2276   2276         P1-021               6   1001.500000           HABITUAL
# 2277   2277              o             213    624.987559          FRECUENTE
#
#      Volumen_cliente
# 0            PEQUENO
# 1            PEQUENO
# 2            PEQUENO
# 3            PEQUENO
# 4            PEQUENO
# ...              ...
# 2273         PEQUENO
# 2274         PEQUENO
# 2275         PEQUENO
# 2276         PEQUENO
# 2277         PEQUENO
#
# [2278 rows x 6 columns]

# %%
clients_group = clients_group.drop(columns=["index", "Total_purchase", "Average"])
clients_group
# Out:
#      Codigo_cliente Frecuencia_cliente Volumen_cliente
# 0          %41-280%          OCACIONAL         PEQUENO
# 1             0-050          OCACIONAL         PEQUENO
# 2            01-001          OCACIONAL         PEQUENO
# 3            01-002          FRECUENTE         PEQUENO
# 4            01-004          FRECUENTE         PEQUENO
# ...             ...                ...             ...
# 2273         P1-014          FRECUENTE         PEQUENO
# 2274         P1-015          OCACIONAL         PEQUENO
# 2275         P1-018           HABITUAL         PEQUENO
# 2276         P1-021           HABITUAL         PEQUENO
# 2277              o          FRECUENTE         PEQUENO
#
# [2278 rows x 3 columns]

# %%
final_df = pd.merge(df, clients_group, on='Codigo_cliente', how='left')
final_df
# Out:
#        Unnamed: 0  Codigo_venta      Fecha  Almacen  Caja   T_C  \
# 0               0          8619 2016-04-01      166    10  6.96
# 1               1          8619 2016-04-01      166    10  6.96
# 2               2          8620 2016-04-01      161    10  6.96
# 3               3          8620 2016-04-01      161    10  6.96
# 4               4          8621 2016-04-01      161    10  6.96
# ...           ...           ...        ...      ...   ...   ...
# 29913       29924         32049 2021-08-05      162    10  6.96
# 29914       29925         32050 2021-08-05      165    10  6.96
# 29915       29926         32050 2021-08-05      165    10  6.96
# 29916       29927         32051 2021-08-05      164    10  6.96
# 29917       29928         32051 2021-08-05      164    10  6.96
#
#       Codigo_cliente                    Nombre_cliente  Codigo_vendedor  \
# 0             60-747                   WILFREDO MENDEZ             73.0
# 1             60-747                   WILFREDO MENDEZ             73.0
# 2             41-286                   SILVERIO CHOQUE             42.0
# 3             41-286                   SILVERIO CHOQUE             42.0
# 4             63-044  EMPRESA CONSTRUCTORA ROLY S.R.L.             42.0
# ...              ...                               ...              ...
# 29913              O                 BENEDICTO ALVAREZ             32.0
# 29914         66-796        CONSTRUCTORA ORBANCO S.R.L             24.0
# 29915         66-796        CONSTRUCTORA ORBANCO S.R.L             24.0
# 29916         60-743                         WIWOGREEN             67.0
# 29917         60-743                         WIWOGREEN             67.0
#
#       Codigo_proyecto  ... Dia_Semana Mes   Ano  Precio_unitario  \
# 0               P-006  ...     Friday   4  2016            24.70
# 1               P-006  ...     Friday   4  2016             8.20
# 2               P-003  ...     Friday   4  2016            11.20
# 3               P-003  ...     Friday   4  2016             5.10
# 4               P-003  ...     Friday   4  2016             8.20
# ...               ...  ...        ...  ..   ...              ...
# 29913              VP  ...   Thursday   8  2021             8.10
# 29914              vp  ...   Thursday   8  2021            49.66
# 29915              vp  ...   Thursday   8  2021            33.55
# 29916              VP  ...   Thursday   8  2021            11.20
# 29917              VP  ...   Thursday   8  2021            19.10
#
#        Ultimo_caracter  Tipo_producto  Nombre_vendedor  Departamento  \
# 0                    C       COMPRADO  Edwin Rodriguez        TARIJA
# 1                    P      PRODUCIDO  Edwin Rodriguez        TARIJA
# 2                    C       COMPRADO     Daniel Ayala        POTOSI
# 3                    C       COMPRADO     Daniel Ayala        POTOSI
# 4                    P      PRODUCIDO     Daniel Ayala        POTOSI
# ...                ...            ...              ...           ...
# 29913                C       COMPRADO  Jhonny Tococosi         ORURO
# 29914                P      PRODUCIDO     Jimmy Quispe        LA_PAZ
# 29915                P      PRODUCIDO     Jimmy Quispe        LA_PAZ
# 29916                C       COMPRADO      Carla Arnez    SANTA_CRUZ
# 29917                C       COMPRADO      Carla Arnez    SANTA_CRUZ
#
#        Frecuencia_cliente  Volumen_cliente
# 0                HABITUAL          PEQUENO
# 1                HABITUAL          PEQUENO
# 2                HABITUAL          PEQUENO
# 3                HABITUAL          PEQUENO
# 4               FRECUENTE          PEQUENO
# ...                   ...              ...
# 29913           FRECUENTE          MEDIANO
# 29914            HABITUAL          PEQUENO
# 29915            HABITUAL          PEQUENO
# 29916           FRECUENTE          PEQUENO
# 29917           FRECUENTE          PEQUENO
#
# [29918 rows x 31 columns]

# %%
final_df = final_df.drop(columns=["Ultimo_caracter","Unnamed: 0"])

# %%
final_df[final_df["Codigo_cliente"] == "o"]
# Out:
#        Codigo_venta      Fecha  Almacen  Caja   T_C Codigo_cliente  \
# 115            8662 2016-04-06      162    10  6.86              o
# 116            8662 2016-04-06      162    10  6.86              o
# 117            8662 2016-04-06      162    10  6.86              o
# 118            8662 2016-04-06      162    10  6.86              o
# 119            8662 2016-04-06      162    10  6.86              o
# ...             ...        ...      ...   ...   ...            ...
# 25814         30655 2021-04-23      162    10  6.96              o
# 25815         30655 2021-04-23      162    10  6.96              o
# 26730         30967 2021-05-21      162    10  6.96              o
# 28082         31459 2021-06-30      162    10  6.96              o
# 29727         31985 2021-08-03      162    10  6.96              o
#
#                 Nombre_cliente  Codigo_vendedor Codigo_proyecto  \
# 115       CLIENTES OCASIONALES             31.0           P-002
# 116       CLIENTES OCASIONALES             31.0           P-002
# 117       CLIENTES OCASIONALES             31.0           P-002
# 118       CLIENTES OCASIONALES             31.0           P-002
# 119       CLIENTES OCASIONALES             31.0           P-002
# ...                        ...              ...             ...
# 25814     YURI HUALLATA FLORES             33.0              VP
# 25815     YURI HUALLATA FLORES             33.0              VP
# 26730             SIMON FLORES             32.0              VP
# 28082                   ZUÑIGA             31.0              VP
# 29727  MACARIO CIPRIAN CONDORI             31.0              VP
#
#           Codigo_producto  ... Total_credito Dia_Semana  Mes   Ano  \
# 115    A350120-063X032N1C  ...          87.2  Wednesday    4  2016
# 116    A350120-063X020N1C  ...          56.4  Wednesday    4  2016
# 117    A115C20-020-100N1P  ...         147.0  Wednesday    4  2016
# 118    A350100-020X020N1C  ...          15.3  Wednesday    4  2016
# 119    A420STD-000-1/2M2C  ...          33.2  Wednesday    4  2016
# ...                   ...  ...           ...        ...  ...   ...
# 25814  A350100-020X020N1C  ...           5.1     Friday    4  2021
# 25815  A350105-032X032N1C  ...          13.5     Friday    4  2021
# 26730  A350050-020-000N1C  ...           9.4     Friday    5  2021
# 28082  A350120-063X032N1C  ...          43.6  Wednesday    6  2021
# 29727  A350022-040X032N1C  ...          87.6    Tuesday    8  2021
#
#        Precio_unitario  Tipo_producto  Nombre_vendedor  Departamento  \
# 115               43.6       COMPRADO  Ma. Esther Tala         ORURO
# 116               56.4       COMPRADO  Ma. Esther Tala         ORURO
# 117                4.9      PRODUCIDO  Ma. Esther Tala         ORURO
# 118                5.1       COMPRADO  Ma. Esther Tala         ORURO
# 119               33.2       COMPRADO  Ma. Esther Tala         ORURO
# ...                ...            ...              ...           ...
# 25814              5.1       COMPRADO     Juan Condori         ORURO
# 25815             13.5       COMPRADO     Juan Condori         ORURO
# 26730              9.4       COMPRADO  Jhonny Tococosi         ORURO
# 28082             43.6       COMPRADO  Ma. Esther Tala         ORURO
# 29727             87.6       COMPRADO  Ma. Esther Tala         ORURO
#
#        Frecuencia_cliente  Volumen_cliente
# 115             FRECUENTE          PEQUENO
# 116             FRECUENTE          PEQUENO
# 117             FRECUENTE          PEQUENO
# 118             FRECUENTE          PEQUENO
# 119             FRECUENTE          PEQUENO
# ...                   ...              ...
# 25814           FRECUENTE          PEQUENO
# 25815           FRECUENTE          PEQUENO
# 26730           FRECUENTE          PEQUENO
# 28082           FRECUENTE          PEQUENO
# 29727           FRECUENTE          PEQUENO
#
# [213 rows x 29 columns]

# %% [markdown]
# ## Results

# %%
final_df
# Out:
#        Codigo_venta      Fecha  Almacen  Caja   T_C Codigo_cliente  \
# 0              8619 2016-04-01      166    10  6.96         60-747
# 1              8619 2016-04-01      166    10  6.96         60-747
# 2              8620 2016-04-01      161    10  6.96         41-286
# 3              8620 2016-04-01      161    10  6.96         41-286
# 4              8621 2016-04-01      161    10  6.96         63-044
# ...             ...        ...      ...   ...   ...            ...
# 29913         32049 2021-08-05      162    10  6.96              O
# 29914         32050 2021-08-05      165    10  6.96         66-796
# 29915         32050 2021-08-05      165    10  6.96         66-796
# 29916         32051 2021-08-05      164    10  6.96         60-743
# 29917         32051 2021-08-05      164    10  6.96         60-743
#
#                          Nombre_cliente  Codigo_vendedor Codigo_proyecto  \
# 0                       WILFREDO MENDEZ             73.0           P-006
# 1                       WILFREDO MENDEZ             73.0           P-006
# 2                       SILVERIO CHOQUE             42.0           P-003
# 3                       SILVERIO CHOQUE             42.0           P-003
# 4      EMPRESA CONSTRUCTORA ROLY S.R.L.             42.0           P-003
# ...                                 ...              ...             ...
# 29913                 BENEDICTO ALVAREZ             32.0              VP
# 29914        CONSTRUCTORA ORBANCO S.R.L             24.0              vp
# 29915        CONSTRUCTORA ORBANCO S.R.L             24.0              vp
# 29916                         WIWOGREEN             67.0              VP
# 29917                         WIWOGREEN             67.0              VP
#
#           Codigo_producto  ... Total_credito Dia_Semana  Mes   Ano  \
# 0      A350050-032-000N1C  ...          49.4     Friday    4  2016
# 1      A115C12-032-100N1P  ...         800.0     Friday    4  2016
# 2      A350100-032X032N1C  ...          22.4     Friday    4  2016
# 3      A350100-020X020N1C  ...          30.6     Friday    4  2016
# 4      A115C12-032-100N1P  ...        3280.0     Friday    4  2016
# ...                   ...  ...           ...        ...  ...   ...
# 29913  A350100-025X025N1C  ...          32.4   Thursday    8  2021
# 29914  A115C10-110-100N1P  ...       39728.0   Thursday    8  2021
# 29915  A115C10-090-100N1P  ...       20130.0   Thursday    8  2021
# 29916  A350100-032X032N1C  ...          22.4   Thursday    8  2021
# 29917  A350100-040X040N1C  ...          38.2   Thursday    8  2021
#
#        Precio_unitario  Tipo_producto  Nombre_vendedor  Departamento  \
# 0                24.70       COMPRADO  Edwin Rodriguez        TARIJA
# 1                 8.20      PRODUCIDO  Edwin Rodriguez        TARIJA
# 2                11.20       COMPRADO     Daniel Ayala        POTOSI
# 3                 5.10       COMPRADO     Daniel Ayala        POTOSI
# 4                 8.20      PRODUCIDO     Daniel Ayala        POTOSI
# ...                ...            ...              ...           ...
# 29913             8.10       COMPRADO  Jhonny Tococosi         ORURO
# 29914            49.66      PRODUCIDO     Jimmy Quispe        LA_PAZ
# 29915            33.55      PRODUCIDO     Jimmy Quispe        LA_PAZ
# 29916            11.20       COMPRADO      Carla Arnez    SANTA_CRUZ
# 29917            19.10       COMPRADO      Carla Arnez    SANTA_CRUZ
#
#        Frecuencia_cliente  Volumen_cliente
# 0                HABITUAL          PEQUENO
# 1                HABITUAL          PEQUENO
# 2                HABITUAL          PEQUENO
# 3                HABITUAL          PEQUENO
# 4               FRECUENTE          PEQUENO
# ...                   ...              ...
# 29913           FRECUENTE          MEDIANO
# 29914            HABITUAL          PEQUENO
# 29915            HABITUAL          PEQUENO
# 29916           FRECUENTE          PEQUENO
# 29917           FRECUENTE          PEQUENO
#
# [29918 rows x 29 columns]

# %%
final_df[(final_df["Total_descuento"]<0) & (final_df["Total_descuento"]>-1)][["Codigo_venta","Total_descuento","Total_venta","Total_credito"]]
# Out:
#       Codigo_venta  Total_descuento  Total_venta  Total_credito
# 3534          9719    -2.000000e-03     33945.87       33945.87
# 3539          9719    -1.164153e-12      8749.20        8749.20
# 3546          9719    -1.862645e-11     98802.00       98802.00
# 3547          9719    -1.164153e-12      5424.00        5424.00

# %%
final_df["Total_descuento"] = final_df["Total_descuento"].where(~((final_df["Total_descuento"]<0) & (final_df["Total_descuento"]>-1)), 0)

# %%
final_df.describe()
# Out:
#        Codigo_venta                          Fecha       Almacen     Caja  \
# count  29918.000000                          29918  29918.000000  29918.0
# mean   19711.475834  2018-12-21 09:03:35.870045184    154.480580     10.0
# min     8619.000000            2016-04-01 00:00:00    111.000000     10.0
# 25%    12455.000000            2017-07-20 00:00:00    161.000000     10.0
# 50%    17401.500000            2018-07-30 00:00:00    162.000000     10.0
# 75%    27280.000000            2020-08-27 00:00:00    163.000000     10.0
# max    32051.000000            2021-08-05 00:00:00    411.000000     10.0
# std     7765.713002                            NaN     19.330336      0.0
#
#                 T_C  Codigo_vendedor  Cantidad_vendida  Precio_total  \
# count  29918.000000     29918.000000      29918.000000  2.991800e+04
# mean       6.928524        37.429641        196.276249  7.225284e+03
# min        6.860000        11.000000          0.500000  5.000000e-01
# 25%        6.860000        22.000000          2.000000  5.130000e+01
# 50%        6.960000        33.000000          4.000000  2.177000e+02
# 75%        6.960000        51.000000         30.000000  1.387500e+03
# max        6.960000        74.000000     164909.560000  5.898700e+06
# std        0.046262        15.576563       1359.286850  7.281930e+04
#
#        Total_descuento  Total_facturado  Total_impuesto   Total_venta  \
# count     29918.000000     2.991800e+04         29918.0  2.991800e+04
# mean        233.927474     6.991357e+03             0.0  6.991357e+03
# min      -64647.370000     5.000000e-01             0.0  5.000000e-01
# 25%           0.000000     5.130000e+01             0.0  5.130000e+01
# 50%           0.000000     2.177000e+02             0.0  2.177000e+02
# 75%           0.000000     1.361500e+03             0.0  1.361500e+03
# max      221014.500000     5.898700e+06             0.0  5.898700e+06
# std        3408.298801     7.231462e+04             0.0  7.231462e+04
#
#        Total_contado  Total_credito           Mes           Ano  \
# count        29918.0   2.991800e+04  29918.000000  29918.000000
# mean             0.0   6.991357e+03      6.443011   2018.479811
# min              0.0   5.000000e-01      4.000000   2016.000000
# 25%              0.0   5.130000e+01      5.000000   2017.000000
# 50%              0.0   2.177000e+02      6.000000   2018.000000
# 75%              0.0   1.361500e+03      8.000000   2020.000000
# max              0.0   5.898700e+06     10.000000   2021.000000
# std              0.0   7.231462e+04      1.733183      1.704587
#
#        Precio_unitario
# count     2.991800e+04
# mean      3.453005e+02
# min       5.000000e-01
# 25%       1.120000e+01
# 50%       2.790000e+01
# 75%       8.210000e+01
# max       1.821495e+06
# std       1.112702e+04

# %%
final_df.count()
# Out:
# Codigo_venta          29918
# Fecha                 29918
# Almacen               29918
# Caja                  29918
# T_C                   29918
# Codigo_cliente        29918
# Nombre_cliente        29918
# Codigo_vendedor       29918
# Codigo_proyecto       29918
# Codigo_producto       29918
# Nombre_producto       29918
# Linea_producto        29918
# Cantidad_vendida      29918
# Precio_total          29918
# Total_descuento       29918
# Total_facturado       29918
# Total_impuesto        29918
# Total_venta           29918
# Total_contado         29918
# Total_credito         29918
# Dia_Semana            29918
# Mes                   29918
# Ano                   29918
# Precio_unitario       29918
# Tipo_producto         29918
# Nombre_vendedor       29918
# Departamento          29918
# Frecuencia_cliente    29918
# Volumen_cliente       29918
# dtype: int64

# %%
final_df.to_csv("./final_document.csv")

# %% [markdown]
# # Extras

# %%
final_df.describe()
# Out:
#        Codigo_venta                          Fecha       Almacen     Caja  \
# count  29918.000000                          29918  29918.000000  29918.0
# mean   19711.475834  2018-12-21 09:03:35.870045184    154.480580     10.0
# min     8619.000000            2016-04-01 00:00:00    111.000000     10.0
# 25%    12455.000000            2017-07-20 00:00:00    161.000000     10.0
# 50%    17401.500000            2018-07-30 00:00:00    162.000000     10.0
# 75%    27280.000000            2020-08-27 00:00:00    163.000000     10.0
# max    32051.000000            2021-08-05 00:00:00    411.000000     10.0
# std     7765.713002                            NaN     19.330336      0.0
#
#                 T_C  Codigo_vendedor  Cantidad_vendida  Precio_total  \
# count  29918.000000     29918.000000      29918.000000  2.991800e+04
# mean       6.928524        37.429641        196.276249  7.225284e+03
# min        6.860000        11.000000          0.500000  5.000000e-01
# 25%        6.860000        22.000000          2.000000  5.130000e+01
# 50%        6.960000        33.000000          4.000000  2.177000e+02
# 75%        6.960000        51.000000         30.000000  1.387500e+03
# max        6.960000        74.000000     164909.560000  5.898700e+06
# std        0.046262        15.576563       1359.286850  7.281930e+04
#
#        Total_descuento  Total_facturado  Total_impuesto   Total_venta  \
# count     29918.000000     2.991800e+04         29918.0  2.991800e+04
# mean        233.927474     6.991357e+03             0.0  6.991357e+03
# min      -64647.370000     5.000000e-01             0.0  5.000000e-01
# 25%           0.000000     5.130000e+01             0.0  5.130000e+01
# 50%           0.000000     2.177000e+02             0.0  2.177000e+02
# 75%           0.000000     1.361500e+03             0.0  1.361500e+03
# max      221014.500000     5.898700e+06             0.0  5.898700e+06
# std        3408.298801     7.231462e+04             0.0  7.231462e+04
#
#        Total_contado  Total_credito           Mes           Ano  \
# count        29918.0   2.991800e+04  29918.000000  29918.000000
# mean             0.0   6.991357e+03      6.443011   2018.479811
# min              0.0   5.000000e-01      4.000000   2016.000000
# 25%              0.0   5.130000e+01      5.000000   2017.000000
# 50%              0.0   2.177000e+02      6.000000   2018.000000
# 75%              0.0   1.361500e+03      8.000000   2020.000000
# max              0.0   5.898700e+06     10.000000   2021.000000
# std              0.0   7.231462e+04      1.733183      1.704587
#
#        Precio_unitario
# count     2.991800e+04
# mean      3.453005e+02
# min       5.000000e-01
# 25%       1.120000e+01
# 50%       2.790000e+01
# 75%       8.210000e+01
# max       1.821495e+06
# std       1.112702e+04
