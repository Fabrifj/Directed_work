# %% [markdown]
# # Reead, tranform  and analize data #

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Temor, raiz de todo mal
# La muerte es una quimera, mientras to existo, no existe la muerte
# y cuento existe ella, ya no existo yo
# lo mejor de la mascara, es que te paraliza
# como los miedos, aquellos que te evitan avanzar en la vida

# %%
total_sells = "total_sells.csv"

# %%
# Read the document
try:
    df_final = pd.read_csv(total_sells) 
    print(f"Excel {total_sells} read correctly, size {df_final.shape}" )
except FileNotFoundError:
    print(f"El archivo '{total_sells}' no se encontró.")
except Exception as e:
    print(f"Ocurrió un error al leer el archivo: {str(e)}")



print(f" Final data frame results {df_final.ndim}")

df_final
# Out:
# Excel total_sells.csv read correctly, size (29929, 20)
#  Final data frame results 2
#        Codigo_venta       Fecha  Almacen  Caja   T_C Codigo_cliente  \
# 0              8619  2016-04-01      166    10  6.96         60-747
# 1              8619  2016-04-01      166    10  6.96         60-747
# 2              8620  2016-04-01      161    10  6.96         41-286
# 3              8620  2016-04-01      161    10  6.96         41-286
# 4              8621  2016-04-01      161    10  6.96         63-044
# ...             ...         ...      ...   ...   ...            ...
# 29924         32049  2021-08-05      162    10  6.96              O
# 29925         32050  2021-08-05      165    10  6.96         66-796
# 29926         32050  2021-08-05      165    10  6.96         66-796
# 29927         32051  2021-08-05      164    10  6.96         60-743
# 29928         32051  2021-08-05      164    10  6.96         60-743
#
# ...

# %% [markdown]
# **Analyze and visualize**

# %%
df_final.describe()
# Out:
#        Codigo_venta       Almacen     Caja           T_C  Codigo_vendedor  \
# count  29929.000000  29929.000000  29929.0  29929.000000     29889.000000
# mean   19712.224064    154.473053     10.0      6.970336        37.445783
# std     7765.808817     19.336806      0.0      1.918150        15.575869
# min     8619.000000    111.000000     10.0      0.860000        11.000000
# 25%    12455.000000    161.000000     10.0      6.860000        22.000000
# 50%    17403.000000    162.000000     10.0      6.960000        34.000000
# 75%    27280.000000    163.000000     10.0      6.960000        51.000000
# max    32051.000000    411.000000     10.0     68.960000        74.000000
#
#        Cantidad_vendida  Precio_total  Total_descuento  Total_facturado  \
# count      29929.000000  2.992900e+04     29929.000000     2.991800e+04
# mean         196.209022  7.234495e+03       245.707391     6.991357e+03
# std         1359.041655  7.283380e+04      3977.524809     7.231462e+04
# ...

# %%
df_final.dtypes
# Out:
# Codigo_venta          int64
# Fecha                object
# Almacen               int64
# Caja                  int64
# T_C                 float64
# Codigo_cliente       object
# Nombre_cliente       object
# Codigo_vendedor     float64
# Codigo_proyecto      object
# Codigo_producto      object
# Nombre_producto      object
# Linea_producto       object
# Cantidad_vendida    float64
# Precio_total        float64
# Total_descuento     float64
# Total_facturado     float64
# Total_impuesto        int64
# Total_venta         float64
# Total_contado         int64
# Total_credito       float64
# dtype: object

# %%
df_final.count()
# Out:
# Codigo_venta        29929
# Fecha               29929
# Almacen             29929
# Caja                29929
# T_C                 29929
# Codigo_cliente      29928
# Nombre_cliente      29928
# Codigo_vendedor     29889
# Codigo_proyecto     29832
# Codigo_producto     29929
# Nombre_producto     29929
# Linea_producto      28849
# Cantidad_vendida    29929
# Precio_total        29929
# Total_descuento     29929
# Total_facturado     29918
# Total_impuesto      29929
# Total_venta         29929
# Total_contado       29929
# Total_credito       29929
# dtype: int64

# %%
# Group by 'Codigo_vendedor' and aggregate both the count and sum of 'Total_venta'
total_sells_by_seller = df_final.groupby("Codigo_vendedor")['Total_venta'].agg(['count', 'sum'])

# Calculate the average sale amount by dividing the sum by the count
total_sells_by_seller['avg_by_sell'] = total_sells_by_seller['sum'] / total_sells_by_seller['count']

total_sells_by_seller
# Out:
#                  count          sum   avg_by_sell
# Codigo_vendedor
# 11.0               138    550211.67   3987.041087
# 14.0              2399  16708642.63   6964.836444
# 15.0                53    262536.20   4953.513208
# 16.0               308  14138599.00  45904.542208
# 17.0              1734  24517265.35  14139.138033
# 18.0                43     66936.27   1556.657442
# 22.0              3094  50062453.20  16180.495540
# 23.0               704   5334829.68   7577.883068
# 24.0               680   3393821.15   4990.913456
# 31.0              1182  12816669.45  10843.205964
# 32.0              2943  14711121.72   4998.682202
# 33.0              1656   3167523.32   1912.755628
# 34.0               279    855004.20   3064.531183
# 41.0               683   9534080.18  13959.121786
# 42.0              2485   7332740.22   2950.800893
# 44.0               375    550060.71   1466.828560
# 45.0               634   1267673.32   1999.484732
# ...

# %%
total_sells_by_seller['sum'].plot(kind="bar", figsize=(10,6), title="Total sells by seller")
plt.xlabel("Codigo de vendedor")
plt.ylabel("Suma de ventas totales")
plt.show()

# %%
total_sells_by_seller['avg_by_sell'].plot(kind="bar", figsize=(10,6), title="avg sells by seller")
plt.xlabel("Codigo de vendedor")
plt.ylabel("Promedio de ventas por vendedor")
plt.show()

# %%
total_sells_by_day = df_final.groupby("Fecha")['Total_venta'].agg(['count', 'sum'])

total_sells_by_day['avg_by_day'] = total_sells_by_day.apply(lambda x : x["sum"]/x["count"] if x["count"]>0  else 0, axis=1 )

total_sells_by_day
# Out:
#             count        sum    avg_by_day
# Fecha
# 2016-04-01     30   77025.60   2567.520000
# 2016-04-02      5    2325.50    465.100000
# 2016-04-04     34   40311.10   1185.620588
# 2016-04-05     25  906060.36  36242.414400
# 2016-04-06     37   34550.80    933.805405
# ...           ...        ...           ...
# 2021-07-31     27  445666.16  16506.154074
# 2021-08-02    130  645252.24   4963.478769
# 2021-08-03     69  194136.66   2813.574783
# 2021-08-04     79  450312.96   5700.164051
# 2021-08-05     47  430202.10   9153.236170
#
# [744 rows x 3 columns]

# %%
total_sells_by_day['avg_by_day'].plot(kind="line", figsize=(10,6), title="avg sells by day")
plt.xlabel("Codigo de vendedor")
plt.ylabel("Promedio de ventas por vendedor")
plt.show()

# %% [markdown]
# # Start  cleaning #

# %%
df_final[df_final["Total_descuento"]<-2]
# Out:
#       Codigo_venta       Fecha  Almacen  Caja   T_C Codigo_cliente  \
# 3542          9719  2016-08-17      111    10  6.86         30-010
#
#      Nombre_cliente  Codigo_vendedor Codigo_proyecto     Codigo_producto  \
# 3542         SEMAPA             16.0           A-327  Z900900-010-111-0Z
#
#        Nombre_producto Linea_producto  Cantidad_vendida  Precio_total  \
# 3542  MARGEN PROYECTOS            NaN               1.0      94861.86
#
#       Total_descuento  Total_facturado  Total_impuesto  Total_venta  \
# 3542        -64647.37        159509.23               0    159509.23
#
#       Total_contado  Total_credito
# 3542              0      159509.23

# %%
df_final.describe()
# Out:
#        Codigo_venta       Almacen     Caja           T_C  Codigo_vendedor  \
# count  29929.000000  29929.000000  29929.0  29929.000000     29889.000000
# mean   19712.224064    154.473053     10.0      6.970336        37.445783
# std     7765.808817     19.336806      0.0      1.918150        15.575869
# min     8619.000000    111.000000     10.0      0.860000        11.000000
# 25%    12455.000000    161.000000     10.0      6.860000        22.000000
# 50%    17403.000000    162.000000     10.0      6.960000        34.000000
# 75%    27280.000000    163.000000     10.0      6.960000        51.000000
# max    32051.000000    411.000000     10.0     68.960000        74.000000
#
#        Cantidad_vendida  Precio_total  Total_descuento  Total_facturado  \
# count      29929.000000  2.992900e+04     29929.000000     2.991800e+04
# mean         196.209022  7.234495e+03       245.707391     6.991357e+03
# std         1359.041655  7.283380e+04      3977.524809     7.231462e+04
# ...

# %%
df_final['Fecha'] = pd.to_datetime(df_final['Fecha'])

# %% [markdown]
# We have some documents with out information, and there are some wird.

# %%
valores_caja_unique = df_final['Caja'].unique()
codigo_cliente_unique = df_final['Codigo_cliente'].unique()
nombre_cliente_unique = df_final['Nombre_cliente'].unique()
codigo_vendedor_unique = df_final['Codigo_vendedor'].unique()
codigo_proyecto_unique = df_final['Codigo_proyecto'].unique()
nombre_producto_unique = df_final['Nombre_producto'].unique()
codigo_producto_unique = df_final['Codigo_producto'].unique()
linea_producto_unique = df_final['Linea_producto'].unique()
print( "valores_caja:", len(valores_caja_unique))
print( "Codigo_cliente:", len(codigo_cliente_unique))
print( "Nombre_cliente:", len(nombre_cliente_unique))
print( "Codigo_vendedor:", len(codigo_vendedor_unique))
print( "Codigo_proyecto:", len(codigo_proyecto_unique))
print( "Nombre_producto:", len(nombre_producto_unique))
print( "Codigo_producto:", len(codigo_producto_unique))
print( "Linea_producto:", len(linea_producto_unique))
# Out:
# valores_caja: 1
# Codigo_cliente: 2281
# Nombre_cliente: 3532
# Codigo_vendedor: 34
# Codigo_proyecto: 157
# Nombre_producto: 1086
# Codigo_producto: 1612
# Linea_producto: 366

# %% [markdown]
# ## Fill dataframe ##

# %% [markdown]
# ### Linea_producto

# %%
# diccionario_resultante = df_clean.groupby('Codigo_producto')['Linea_producto'].unique().apply(list).to_dict()
# print(diccionario_resultante)

# %%
product_nolinea = df_final[df_final['Linea_producto'].isnull()]["Nombre_producto"].unique()
print(len(product_nolinea))
# Out:
# 254

# %% [markdown]
# Check if any product that have a "linea_producto" is nan

# %%
result_lp = df_final.groupby(["Codigo_producto"]).agg({
    "Codigo_producto": "count",
    "Linea_producto": "count"
})
# Flatten the MultiIndex and then rename the columns directly
result_lp.columns = ['total_count_codigo', 'total_count_linea']

result_lp["Error_name"] = result_lp["total_count_codigo"] != result_lp["total_count_linea"]
result_filtered = result_lp[(result_lp["Error_name"]) & (result_lp["total_count_codigo"]>2) ]
print(result_filtered.sort_values(["total_count_codigo"],ascending=False))
print(result_filtered.index)
codes_df = pd.DataFrame({'Codigo_producto': result_filtered.index})
# Out:
#                     total_count_codigo  total_count_linea  Error_name
# Codigo_producto
# A330040-020-000S1C                 102                  0        True
# Z100100-010-160-0Z                  38                  0        True
# A330010-020-000S1C                  36                  0        True
# Z900900-010-024-0Z                  30                  0        True
# A330040-060-000S1C                  23                  0        True
# ...                                ...                ...         ...
# A310060-032-000S1C                   3                  0        True
# A350300-063-000N1C                   3                  0        True
# A310070-025-000S1C                   3                  0        True
# R310012-020X020N1C                   3                  0        True
# A115C10-110-100C1P                   3                  0        True
#
# [107 rows x 3 columns]
# Index(['A115C10-110-100C1P', 'A130-PE05-000N1C', 'A130-PE05-000N2P',
# ...

# %%
df_final.groupby(["Codigo_producto"])["Codigo_venta"].count().quantile(0.5)
# Out:
# 2.0

# %%
df_final["Linea_producto"]= df_final.apply(lambda x: "SERVICIO" if str(x["Codigo_producto"]).startswith("Z") else x["Linea_producto"], axis=1)

df_final[df_final["Linea_producto"]=="SERVICIO"]
# Out:
#        Codigo_venta      Fecha  Almacen  Caja   T_C Codigo_cliente  \
# 104            8656 2016-04-06      111    10  6.86         64-062
# 240            8710 2016-04-13      166    10  6.86         60-736
# 355            8746 2016-04-18      111    10  6.96         64-742
# 356            8746 2016-04-18      111    10  6.96         64-742
# 357            8746 2016-04-18      111    10  6.96         64-742
# ...             ...        ...      ...   ...   ...            ...
# 29692         31981 2021-08-02      164    10  6.96         30-103
# 29693         31981 2021-08-02      164    10  6.96         30-103
# 29694         31981 2021-08-02      164    10  6.96         30-103
# 29712         31981 2021-08-02      164    10  6.96         30-103
# 29803         32005 2021-08-04      111    10  6.96         21-024
#
#                     Nombre_cliente  Codigo_vendedor Codigo_proyecto  \
# 104                      GUTIERREZ             14.0           P-001
# ...

# %%
products_nonLinea = df_final[df_final["Linea_producto"].isnull()]["Codigo_producto"]
print(len(products_nonLinea.unique()))
print(products_nonLinea.count())
# Out:
# 197
# 850

# %%
df_final["Linea_producto"] = df_final["Linea_producto"].fillna("DESCONOCIDO")

# %% [markdown]
# Obtenemos la lista de producotos sin linea de producto

# %%
# unique_products = df_final.groupby('Codigo_producto')['Nombre_producto'].first().reset_index()
# matched_df = pd.merge(codes_df, unique_products, on='Codigo_producto', how='left')

# matched_df.to_csv("./nonLinea_productos.csv")

# %%
df_final[df_final["Nombre_producto"]=="CODIGO ERRONEO"]
# Out:
#        Codigo_venta      Fecha  Almacen  Caja   T_C Codigo_cliente  \
# 17285         21595 2019-05-15      164    10  6.96         01-780
# 18235         21865 2019-06-01      165    10  6.96         62-379
# 24223         27868 2020-10-06      111    10  6.96         64-401
# 26043         30731 2021-04-28      111    10  6.96         04-001
#
#                              Nombre_cliente  Codigo_vendedor Codigo_proyecto  \
# 17285  CRISTINA CONSUELO AGUILERA DE MORENO             65.0           ASC14
# 18235          FRANCO DAVID ADUVIRI PAREDES             22.0              VP
# 24223                    M3 ARQUITECTOS SRL             14.0              VP
# 26043                         PIL ANDINA SA             14.0           AB031
#
#           Codigo_producto Nombre_producto Linea_producto  Cantidad_vendida  \
# 17285  A115C10-110-100C1P  CODIGO ERRONEO    DESCONOCIDO               2.0
# 18235  A115C10-110-100C1P  CODIGO ERRONEO    DESCONOCIDO             300.0
# ...

# %%
df_final[df_final["Linea_producto"]=="ROLLO 260m X 7.5m"][["Codigo_producto", "Nombre_producto"]]
# Out:
#         Codigo_producto                Nombre_producto
# 472    A130-G075-000N1C  GEOMEMBRANA HDPE GM13  0.75mm
# 482    A130-G075-000N1C  GEOMEMBRANA HDPE GM13  0.75mm
# 654    A130-G075-000N1C  GEOMEMBRANA HDPE GM13  0.75mm
# 2271   A130-G075-000N1C  GEOMEMBRANA HDPE GM13  0.75mm
# 2613   A130-G075-000N1C  GEOMEMBRANA HDPE GM13  0.75mm
# ...                 ...                            ...
# 28559  A130-G075-000N1C  GEOMEMBRANA HDPE GM13  0.75mm
# 29320  A130-G075-000N4C     GEOMEMBRANA HDPE DE 0.75mm
# 29416  A130-G075-000N4C     GEOMEMBRANA HDPE DE 0.75mm
# 29417  A130-G075-000N4C     GEOMEMBRANA HDPE DE 0.75mm
# 29422  A130-G075-000N4C     GEOMEMBRANA HDPE DE 0.75mm
#
# [144 rows x 2 columns]

# %% [markdown]
# Para una linea de producto hay mas de un producto

# %% [markdown]
# ### Codigo_proyecto

# %%
df_final[df_final["Codigo_proyecto"].isna()]
# Out:
#        Codigo_venta      Fecha  Almacen  Caja   T_C Codigo_cliente  \
# 4368           9978 2016-09-15      111    10  6.86         30-034
# 4369           9978 2016-09-15      111    10  6.86         30-034
# 4370           9978 2016-09-15      111    10  6.86         30-034
# 4371           9978 2016-09-15      111    10  6.86         30-034
# 4558          10041 2016-09-23      162    10  6.86              o
# ...             ...        ...      ...   ...   ...            ...
# 24932         28124 2020-10-22      161    10  6.96         21-052
# 27503         31276 2021-06-16      161    10  6.96         60-146
# 27504         31276 2021-06-16      161    10  6.96         60-146
# 28301         31524 2021-07-05      163    10  6.96              O
# 28302         31524 2021-07-05      163    10  6.96              O
#
#                            Nombre_cliente  Codigo_vendedor Codigo_proyecto  \
# 4368                      EMAPAS - SACABA             14.0             NaN
# ...

# %%
df_final.groupby(["Codigo_proyecto"]).count().sort_values(["Codigo_venta"], ascending=False)
# Out:
#                  Codigo_venta  Fecha  Almacen   Caja    T_C  Codigo_cliente  \
# Codigo_proyecto
# VP                      25276  25276    25276  25276  25276           25276
# P-004                     742    742      742    742    742             742
# vp                        692    692      692    692    692             692
# P-002                     653    653      653    653    653             653
# P-001                     615    615      615    615    615             615
# ...                       ...    ...      ...    ...    ...             ...
# ASC13                       1      1        1      1      1               1
# ASC09                       1      1        1      1      1               1
# ASC08                       1      1        1      1      1               1
# ASC07                       1      1        1      1      1               1
# ALP01                       1      1        1      1      1               1
#
# ...

# %% [markdown]
# 30000 Ventas de las VP a realizado las 25000 equivale 83%

# %%
df_final[df_final["Codigo_proyecto"]=="VP"]["Codigo_cliente"].unique()
# Out:
# array(['72-005', '11-003', '64-447', ..., '61-350', '66-039', '65-258'],
#       dtype=object)

# %%
df_final["Codigo_proyecto"] = df_final["Codigo_proyecto"].fillna("VP")

# %% [markdown]
# ### Total_facturado

# %%
df_final[df_final['Total_facturado'].isna()]
# Out:
#        Codigo_venta      Fecha  Almacen  Caja   T_C Codigo_cliente  \
# 3271           9634 2016-08-12      163    10  6.96              O
# 3551           9719 2016-08-17      111    10  6.86         30-010
# 7826          12575 2017-07-31      111    10  6.86         30-011
# 16271         21303 2019-04-25      111    10  6.96         66-026
# 18177         21849 2019-05-31      111    10  6.96         68-963
# 18178         21849 2019-05-31      111    10  6.96         68-963
# 18179         21849 2019-05-31      111    10  6.96         68-963
# 24496         27966 2020-10-11      161    10  1.00            NaN
# 25353         30494 2021-04-10      161    10  6.86         02-581
# 25355         30494 2021-04-10      161    10  6.86         02-581
# 28190         31488 2021-07-02      162    10  6.96         61-026
#
#               Nombre_cliente  Codigo_vendedor Codigo_proyecto  \
# 3271                 CACERES             53.0              VP
# ...

# %%
df_final[df_final['Total_venta']==0]
# Out:
#        Codigo_venta      Fecha  Almacen  Caja   T_C Codigo_cliente  \
# 3271           9634 2016-08-12      163    10  6.96              O
# 3551           9719 2016-08-17      111    10  6.86         30-010
# 7826          12575 2017-07-31      111    10  6.86         30-011
# 16271         21303 2019-04-25      111    10  6.96         66-026
# 18177         21849 2019-05-31      111    10  6.96         68-963
# 18178         21849 2019-05-31      111    10  6.96         68-963
# 18179         21849 2019-05-31      111    10  6.96         68-963
# 24496         27966 2020-10-11      161    10  1.00            NaN
# 25353         30494 2021-04-10      161    10  6.86         02-581
# 25355         30494 2021-04-10      161    10  6.86         02-581
# 28190         31488 2021-07-02      162    10  6.96         61-026
#
#               Nombre_cliente  Codigo_vendedor Codigo_proyecto  \
# 3271                 CACERES             53.0              VP
# ...

# %%
df_final['Total_facturado'] = df_final['Total_facturado'].fillna(0)

# %% [markdown]
# ### Nombre cliente y Codigo cliente

# %%
df_final[df_final["Nombre_cliente"].isna()]
# Out:
#        Codigo_venta      Fecha  Almacen  Caja  T_C Codigo_cliente  \
# 24496         27966 2020-10-11      161    10  1.0            NaN
#
#       Nombre_cliente  Codigo_vendedor Codigo_proyecto     Codigo_producto  \
# 24496            NaN              NaN              VP  A115C08-110-100N1P
#
#                 Nombre_producto             Linea_producto  Cantidad_vendida  \
# 24496  SUPERTUBO® HDPE DE 110mm  ®PE100 SDR21 PN8 ISO 4427               0.0
#
#        Precio_total  Total_descuento  Total_facturado  Total_impuesto  \
# 24496           0.0              0.0              0.0               0
#
#        Total_venta  Total_contado  Total_credito
# 24496          0.0              0            0.0

# %%
df_final = df_final.drop(df_final.index[24496])

# %% [markdown]
# ### Codigo vendedor

# %%
df_final[df_final["Codigo_vendedor"].isna()].count()
# Out:
# Codigo_venta        39
# Fecha               39
# Almacen             39
# Caja                39
# T_C                 39
# Codigo_cliente      39
# Nombre_cliente      39
# Codigo_vendedor      0
# Codigo_proyecto     39
# Codigo_producto     39
# Nombre_producto     39
# Linea_producto      39
# Cantidad_vendida    39
# Precio_total        39
# Total_descuento     39
# Total_facturado     39
# Total_impuesto      39
# Total_venta         39
# Total_contado       39
# Total_credito       39
# dtype: int64

# %% [markdown]
# Rellenar con la tendencia de ventas ese ano y ventas pasadas

# %%
def estimate_vendor_code(df,row):
    vendor_by_date =estimate_vendor_by_sell_date(df,row)
    vendor_by_client = estimate_vendor_by_client(df,row)
    vendor_combined = pd.concat([vendor_by_client,vendor_by_date])
    vendor_grouped = vendor_combined.groupby(["Codigo_vendedor"])['Percentage'].sum().reset_index(name='TotalPercentage')
    vendor_grouped["TotalPercentage"] = vendor_grouped["TotalPercentage"] / 2
    return vendor_grouped[vendor_grouped["TotalPercentage"] == vendor_grouped["TotalPercentage"].max()]

def estimate_vendor_by_sell_date(df,row):
    filtered_df = df[(df['Fecha'].dt.year == row["Fecha"].year) & (df['Almacen'] == row["Almacen"])]
    vendor_counts = filtered_df.groupby(["Codigo_vendedor"])["Codigo_venta"].count().reset_index(name='Count')
    total_rows = len(filtered_df)
    vendor_counts["Percentage"] = (vendor_counts["Count"].apply(lambda x : x / total_rows) * 100)
    return vendor_counts

def estimate_vendor_by_client(df,row):
    filtered_df = df[df["Codigo_cliente"]==row["Codigo_cliente"]]
    vendor_counts = filtered_df.groupby(["Codigo_vendedor"])["Codigo_venta"].count().reset_index(name='Count')
    total_rows = len(filtered_df)
    vendor_counts["Percentage"] = (vendor_counts["Count"].apply(lambda x : x / total_rows) * 100)
    return vendor_counts

results = []
for index,row in df_final[df_final["Codigo_vendedor"].isna()].iterrows():
    results.append(estimate_vendor_code(df_final, row))

result = pd.concat(results)   
result
# Out:
#    Codigo_vendedor  TotalPercentage
# 0             22.0        74.925816
# 1             32.0        64.474923
# 4             17.0        23.130342
# 4             17.0        23.130342
# 4             17.0        23.130342
# 4             17.0        23.130342
# 4             17.0        23.130342
# 2             17.0        28.776435
# 2             17.0        28.776435
# 2             17.0        28.776435
# 2             17.0        28.776435
# 2             17.0        28.776435
# 2             17.0        28.776435
# 2             17.0        28.776435
# 1             32.0        46.667029
# 1             32.0        52.420997
# 1             32.0        52.420997
# 1             32.0        52.420997
# 1             32.0        52.420997
# 1             32.0        29.563854
# 1             32.0        55.887383
# 3             17.0        47.806122
# 3             17.0        47.806122
# 3             17.0        47.806122
# 3             17.0        47.806122
# ...

# %%
df_final['Codigo_vendedor'] = df_final['Codigo_vendedor'].where(df_final['Codigo_venta']!= 11907, 22)
df_final['Codigo_vendedor'] = df_final['Codigo_vendedor'].where(df_final['Codigo_venta']!= 11924, 32)
df_final['Codigo_vendedor'] = df_final['Codigo_vendedor'].where(df_final['Codigo_venta']!= 12498, 17)
df_final['Codigo_vendedor'] = df_final['Codigo_vendedor'].where(df_final['Codigo_venta']!= 16449, 17)
df_final['Codigo_vendedor'] = df_final['Codigo_vendedor'].where(df_final['Codigo_venta']!= 16927, 32)
df_final['Codigo_vendedor'] = df_final['Codigo_vendedor'].where(df_final['Codigo_venta']!= 17002, 32)
df_final['Codigo_vendedor'] = df_final['Codigo_vendedor'].where(df_final['Codigo_venta']!= 17183, 32)
df_final['Codigo_vendedor'] = df_final['Codigo_vendedor'].where(df_final['Codigo_venta']!= 17273, 32)
df_final['Codigo_vendedor'] = df_final['Codigo_vendedor'].where(df_final['Codigo_venta']!= 21601, 17)
df_final['Codigo_vendedor'] = df_final['Codigo_vendedor'].where(df_final['Codigo_venta']!= 22393, 42)
df_final['Codigo_vendedor'] = df_final['Codigo_vendedor'].where(df_final['Codigo_venta']!= 28127, 32)
df_final['Codigo_vendedor'] = df_final['Codigo_vendedor'].where(df_final['Codigo_venta']!= 31415, 32)

# %% [markdown]
# ##  Find and remplace anomalies ##

# %% [markdown]
# ### T_C

# %%
df_final["T_C"] = df_final["T_C"].apply(lambda x: 6.96  if x>6.96 or x<6.86  else x)
df_final["T_C"] = df_final["T_C"].fillna(6.96)
df_final["T_C"].mean()
# Out:
# 6.928521191600581

# %% [markdown]
# ### Total_ventas Y Total_credito

# %%
df_final[df_final["Total_venta"]==0]
# Out:
#        Codigo_venta      Fecha  Almacen  Caja   T_C Codigo_cliente  \
# 3271           9634 2016-08-12      163    10  6.96              O
# 3551           9719 2016-08-17      111    10  6.86         30-010
# 7826          12575 2017-07-31      111    10  6.86         30-011
# 16271         21303 2019-04-25      111    10  6.96         66-026
# 18177         21849 2019-05-31      111    10  6.96         68-963
# 18178         21849 2019-05-31      111    10  6.96         68-963
# 18179         21849 2019-05-31      111    10  6.96         68-963
# 25353         30494 2021-04-10      161    10  6.86         02-581
# 25355         30494 2021-04-10      161    10  6.86         02-581
# 28190         31488 2021-07-02      162    10  6.96         61-026
#
#               Nombre_cliente  Codigo_vendedor Codigo_proyecto  \
# 3271                 CACERES             53.0              VP
# 3551                  SEMAPA             16.0           A-327
# ...

# %% [markdown]
# Son donaciones por parte de aguatuya

# %%
df_final = df_final[df_final["Total_venta"]!=0]

# %% [markdown]
# ### Total_descuento

# %%
df_final[df_final["Total_descuento"] < 0 ]
# Out:
#        Codigo_venta      Fecha  Almacen  Caja   T_C Codigo_cliente  \
# 3              8620 2016-04-01      161    10  6.96         41-286
# 4              8621 2016-04-01      161    10  6.96         63-044
# 25             8629 2016-04-01      162    10  6.96         62-987
# 30             8630 2016-04-02      163    10  6.86         64-070
# 39             8633 2016-04-04      111    10  6.96         11-021
# ...             ...        ...      ...   ...   ...            ...
# 29825         32016 2021-08-04      162    10  6.96              O
# 29835         32017 2021-08-04      165    10  6.96         30-011
# 29870         32031 2021-08-05      162    10  6.96         62-087
# 29913         32042 2021-08-05      165    10  6.96         61-310
# 29926         32050 2021-08-05      165    10  6.96         66-796
#
#                                  Nombre_cliente  Codigo_vendedor  \
# 3                               SILVERIO CHOQUE             42.0
# ...

# %%
df_final["Total_descuento"] = df_final["Total_descuento"].where(~((df_final["Total_descuento"]<0) & (df_final["Codigo_venta"]!=9719)), 0)

# %%
df_final[df_final["Codigo_venta"]==9719]
# Out:
#       Codigo_venta      Fecha  Almacen  Caja   T_C Codigo_cliente  \
# 3525          9719 2016-08-17      111    10  6.86         30-010
# 3526          9719 2016-08-17      111    10  6.86         30-010
# 3527          9719 2016-08-17      111    10  6.86         30-010
# 3528          9719 2016-08-17      111    10  6.86         30-010
# 3529          9719 2016-08-17      111    10  6.86         30-010
# 3530          9719 2016-08-17      111    10  6.86         30-010
# 3531          9719 2016-08-17      111    10  6.86         30-010
# 3532          9719 2016-08-17      111    10  6.86         30-010
# 3533          9719 2016-08-17      111    10  6.86         30-010
# 3534          9719 2016-08-17      111    10  6.86         30-010
# 3535          9719 2016-08-17      111    10  6.86         30-010
# 3536          9719 2016-08-17      111    10  6.86         30-010
# 3537          9719 2016-08-17      111    10  6.86         30-010
# ...

# %%
df_final[df_final["Total_descuento"]<-2]
# Out:
#       Codigo_venta      Fecha  Almacen  Caja   T_C Codigo_cliente  \
# 3542          9719 2016-08-17      111    10  6.86         30-010
#
#      Nombre_cliente  Codigo_vendedor Codigo_proyecto     Codigo_producto  \
# 3542         SEMAPA             16.0           A-327  Z900900-010-111-0Z
#
#        Nombre_producto Linea_producto  Cantidad_vendida  Precio_total  \
# 3542  MARGEN PROYECTOS       SERVICIO               1.0      94861.86
#
#       Total_descuento  Total_facturado  Total_impuesto  Total_venta  \
# 3542        -64647.37        159509.23               0    159509.23
#
#       Total_contado  Total_credito
# 3542              0      159509.23

# %%
df_final.describe()
# Out:
#        Codigo_venta                          Fecha       Almacen     Caja  \
# count  29918.000000                          29918  29918.000000  29918.0
# mean   19711.475834  2018-12-21 09:03:35.870045184    154.480580     10.0
# min     8619.000000            2016-04-01 00:00:00    111.000000     10.0
# 25%    12455.000000            2017-07-20 00:00:00    161.000000     10.0
# 50%    17401.500000            2018-07-30 00:00:00    162.000000     10.0
# 75%    27280.000000            2020-08-27 00:00:00    163.000000     10.0
# max    32051.000000            2021-08-05 00:00:00    411.000000     10.0
# std     7765.713002                            NaN     19.330336      0.0
#
#                 T_C  Codigo_vendedor  Cantidad_vendida  Precio_total  \
# count  29918.000000     29918.000000      29918.000000  2.991800e+04
# mean       6.928524        37.429641        196.276249  7.225284e+03
# min        6.860000        11.000000          0.500000  5.000000e-01
# ...

# %%
df_final[df_final["Total_descuento"] < -1 ].sort_values(by="Total_descuento")
# Out:
#       Codigo_venta      Fecha  Almacen  Caja   T_C Codigo_cliente  \
# 3542          9719 2016-08-17      111    10  6.86         30-010
#
#      Nombre_cliente  Codigo_vendedor Codigo_proyecto     Codigo_producto  \
# 3542         SEMAPA             16.0           A-327  Z900900-010-111-0Z
#
#        Nombre_producto Linea_producto  Cantidad_vendida  Precio_total  \
# 3542  MARGEN PROYECTOS       SERVICIO               1.0      94861.86
#
#       Total_descuento  Total_facturado  Total_impuesto  Total_venta  \
# 3542        -64647.37        159509.23               0    159509.23
#
#       Total_contado  Total_credito
# 3542              0      159509.23

# %% [markdown]
# ### Linea de producto

# %%
len(df_final[df_final["Linea_producto"]=="ELIMINADO"])
# Out:
# 0

# %%
df_final[df_final["Codigo_producto"].str.startswith("Z")]
# Out:
#        Codigo_venta      Fecha  Almacen  Caja   T_C Codigo_cliente  \
# 104            8656 2016-04-06      111    10  6.86         64-062
# 240            8710 2016-04-13      166    10  6.86         60-736
# 355            8746 2016-04-18      111    10  6.96         64-742
# 356            8746 2016-04-18      111    10  6.96         64-742
# 357            8746 2016-04-18      111    10  6.96         64-742
# ...             ...        ...      ...   ...   ...            ...
# 29692         31981 2021-08-02      164    10  6.96         30-103
# 29693         31981 2021-08-02      164    10  6.96         30-103
# 29694         31981 2021-08-02      164    10  6.96         30-103
# 29712         31981 2021-08-02      164    10  6.96         30-103
# 29803         32005 2021-08-04      111    10  6.96         21-024
#
#                     Nombre_cliente  Codigo_vendedor Codigo_proyecto  \
# 104                      GUTIERREZ             14.0           P-001
# ...

# %%
df_final[df_final["Nombre_producto"].str.startswith("SERVICIO")]
# Out:
#        Codigo_venta      Fecha  Almacen  Caja   T_C Codigo_cliente  \
# 355            8746 2016-04-18      111    10  6.96         64-742
# 360            8746 2016-04-18      111    10  6.96         64-742
# 442            8769 2016-04-21      111    10  6.96         62-988
# 443            8769 2016-04-21      111    10  6.96         62-988
# 523            8799 2016-04-26      161    10  6.96         41-867
# ...             ...        ...      ...   ...   ...            ...
# 29690         31981 2021-08-02      164    10  6.96         30-103
# 29691         31981 2021-08-02      164    10  6.96         30-103
# 29692         31981 2021-08-02      164    10  6.96         30-103
# 29693         31981 2021-08-02      164    10  6.96         30-103
# 29694         31981 2021-08-02      164    10  6.96         30-103
#
#                          Nombre_cliente  Codigo_vendedor Codigo_proyecto  \
# 355                        ROGER AGREDA             61.0           A-312
# ...

# %% [markdown]
# ## Results

# %%
df_final.describe()
# Out:
#        Codigo_venta                          Fecha       Almacen     Caja  \
# count  29918.000000                          29918  29918.000000  29918.0
# mean   19711.475834  2018-12-21 09:03:35.870045184    154.480580     10.0
# min     8619.000000            2016-04-01 00:00:00    111.000000     10.0
# 25%    12455.000000            2017-07-20 00:00:00    161.000000     10.0
# 50%    17401.500000            2018-07-30 00:00:00    162.000000     10.0
# 75%    27280.000000            2020-08-27 00:00:00    163.000000     10.0
# max    32051.000000            2021-08-05 00:00:00    411.000000     10.0
# std     7765.713002                            NaN     19.330336      0.0
#
#                 T_C  Codigo_vendedor  Cantidad_vendida  Precio_total  \
# count  29918.000000     29918.000000      29918.000000  2.991800e+04
# mean       6.928524        37.429641        196.276249  7.225284e+03
# min        6.860000        11.000000          0.500000  5.000000e-01
# ...

# %%
# grouped_agg = df.groupby(['ColumnToGroupBy'])['ColumnToAggregate'].agg(Count=('ColumnToAggregate', 'count'), Average=('ColumnToAggregate', 'mean'))

# %%
df_final.count()
# Out:
# Codigo_venta        29918
# Fecha               29918
# Almacen             29918
# Caja                29918
# T_C                 29918
# Codigo_cliente      29918
# Nombre_cliente      29918
# Codigo_vendedor     29918
# Codigo_proyecto     29918
# Codigo_producto     29918
# Nombre_producto     29918
# Linea_producto      29918
# Cantidad_vendida    29918
# Precio_total        29918
# Total_descuento     29918
# Total_facturado     29918
# Total_impuesto      29918
# Total_venta         29918
# Total_contado       29918
# Total_credito       29918
# dtype: int64

# %%
df_final.to_csv("./clean_sells.csv")

# %%
df_final[df_final["Codigo_venta"]==9719]
# Out:
#       Codigo_venta      Fecha  Almacen  Caja   T_C Codigo_cliente  \
# 3525          9719 2016-08-17      111    10  6.86         30-010
# 3526          9719 2016-08-17      111    10  6.86         30-010
# 3527          9719 2016-08-17      111    10  6.86         30-010
# 3528          9719 2016-08-17      111    10  6.86         30-010
# 3529          9719 2016-08-17      111    10  6.86         30-010
# 3530          9719 2016-08-17      111    10  6.86         30-010
# 3531          9719 2016-08-17      111    10  6.86         30-010
# 3532          9719 2016-08-17      111    10  6.86         30-010
# 3533          9719 2016-08-17      111    10  6.86         30-010
# 3534          9719 2016-08-17      111    10  6.86         30-010
# 3535          9719 2016-08-17      111    10  6.86         30-010
# 3536          9719 2016-08-17      111    10  6.86         30-010
# 3537          9719 2016-08-17      111    10  6.86         30-010
# ...
